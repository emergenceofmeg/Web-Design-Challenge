# %%
import pandas as pd 
from

# %%
#Csv path 
csv_path = "weather_df.csv"

# Read weather data
weather_data = pd.read_csv(csv_path)

# %%
weather_data.columns
# Out:
# Index(['Unnamed: 0', 'CityID', 'City', 'Lat', 'Lng', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
weather_data.drop(columns=['Unnamed: 0'])
# Out:
#       CityID             City      Lat       Lng  Max Temp  Humidity  \
# 0    2017215           Sangar  63.9242  127.4739    -25.51        99
# 1    3833367          Ushuaia -54.8000  -68.3000     54.91        89
# 2    5855927             Hilo  19.7297 -155.0900     88.29        91
# 3     286621          Salalah  17.0151   54.0924     72.55        72
# 4    5880054           Barrow  71.2906 -156.7887     -3.98        77
# ..       ...              ...      ...       ...       ...       ...
# 544  2126199         Cherskiy  68.7500  161.3000    -51.83       100
# 545   779683       Hammerfest  70.6634   23.6821     30.65        64
# 546  2023929  Gornorechenskiy  44.2624  135.1133     19.20        63
# 547  2641108             Oban  56.4127   -5.4706     47.37        79
# 548  6620339         Karratha -20.7377  116.8463     91.96        40
#
#      Cloudiness  Wind Speed Country        Date
# 0            99        2.66      RU  1672970571
# ...

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_html = pd.DataFrame.to_html(weather_df, header=True, index=True, escape=True)

# %%
print(weather_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>CityID</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2017215</td>
#       <td>Sangar</td>
#       <td>63.9242</td>
#       <td>127.4739</td>
#       <td>-25.51</td>
#       <td>99</td>
#       <td>99</td>
#       <td>2.66</td>
#       <td>RU</td>
#       <td>1672970571</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3833367</td>
#       <td>Ushuaia</td>
#       <td>-54.8000</td>
#       <td>-68.3000</td>
#       <td>54.91</td>
#       <td>89</td>
#       <td>100</td>
#       <td>11.83</td>
#       <td>AR</td>
#       <td>1672970572</td>
# ...
